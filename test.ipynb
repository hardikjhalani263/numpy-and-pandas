# %%
import pandas as pd

# %%
df = pd.read_csv(r'/content/userbehaviour.csv')

# %%
df
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0      1001                   17                         634            1
# 1      1002                    0                          54            0
# 2      1003                   37                         207            0
# 3      1004                   32                         445            1
# 4      1005                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df.head(3)
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
# 2    1003                   37                         207            0
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed

# %%
df.tail(4)
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes     Status
# 995        6                     8                  1327  Installed
# 996        6                     1                  1936  Installed
# 997        5                     1                  3436  Installed
# 998        4                     2                  4039  Installed

# %%
df.shape
# Out:
# (999, 8)

# %%
df.columns
# Out:
# Index(['userid', 'Average Screen Time', 'Average Spent on App (INR)',
#        'Left Review', 'Ratings', 'New Password Request',
#        'Last Visited Minutes', 'Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# userid                         int64
# Average Screen Time            int64
# Average Spent on App (INR)     int64
# Left Review                    int64
# Ratings                        int64
# New Password Request           int64
# Last Visited Minutes           int64
# Status                        object
# dtype: object

# %%
df.describe()
# Out:
#             userid  Average Screen Time  Average Spent on App (INR)  \
# count   999.000000           999.000000                  999.000000
# mean   1500.000000            24.390390                  424.415415
# std     288.530761            14.235415                  312.365695
# min    1001.000000             0.000000                    0.000000
# 25%    1250.500000            12.000000                   96.000000
# 50%    1500.000000            24.000000                  394.000000
# 75%    1749.500000            36.000000                  717.500000
# max    1999.000000            50.000000                  998.000000
#
#        Left Review     Ratings  New Password Request  Last Visited Minutes
# count   999.000000  999.000000            999.000000            999.000000
# mean      0.497497    6.513514              4.941942           5110.898899
# std       0.500244    2.701511              2.784626           8592.036516
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   userid                      999 non-null    int64
#  1   Average Screen Time         999 non-null    int64
#  2   Average Spent on App (INR)  999 non-null    int64
#  3   Left Review                 999 non-null    int64
#  4   Ratings                     999 non-null    int64
#  5   New Password Request        999 non-null    int64
#  6   Last Visited Minutes        999 non-null    int64
#  7   Status                      999 non-null    object
# dtypes: int64(7), object(1)
# memory usage: 62.6+ KB

# %%
df.loc[3:8],['userid' , 'left review' , 'rating']
# Out:
# (   userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
#  3    1004                   32                         445            1
#  4    1005                   45                         427            1
#  5    1006                   28                         599            0
#  6    1007                   49                         887            1
#  7    1008                    8                          31            0
#  8    1009                   28                         741            1
#
#     Ratings  New Password Request  Last Visited Minutes     Status
#  3        6                     2                   799  Installed
#  4        5                     6                  3668  Installed
#  5        9                     4                  2878  Installed
#  6        9                     6                  4481  Installed
#  7        2                     1                  1715  Installed
# ...

# %%
df.iloc[3:8], [ 0,1,2,3,4]
# Out:
# (   userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
#  3    1004                   32                         445            1
#  4    1005                   45                         427            1
#  5    1006                   28                         599            0
#  6    1007                   49                         887            1
#  7    1008                    8                          31            0
#
#     Ratings  New Password Request  Last Visited Minutes     Status
#  3        6                     2                   799  Installed
#  4        5                     6                  3668  Installed
#  5        9                     4                  2878  Installed
#  6        9                     6                  4481  Installed
#  7        2                     1                  1715  Installed  ,
#  [0, 1, 2, 3, 4])

# %%
df['userid'].value_counts()
# Out:
# userid
# 1999    1
# 1001    1
# 1002    1
# 1003    1
# 1004    1
#        ..
# 1012    1
# 1011    1
# 1010    1
# 1009    1
# 1008    1
# Name: count, Length: 999, dtype: int64

# %%
df['Ratings'].value_counts()
# Out:
# Ratings
# 9     142
# 5     141
# 10    137
# 7     136
# 8     133
# 6     131
# 2      42
# 0      38
# 4      35
# 3      32
# 1      32
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# userid                        0
# Average Screen Time           0
# Average Spent on App (INR)    0
# Left Review                   0
# Ratings                       0
# New Password Request          0
# Last Visited Minutes          0
# Status                        0
# dtype: int64

# %%
df ['userid'].mode()
# Out:
# 0      1001
# 1      1002
# 2      1003
# 3      1004
# 4      1005
#        ...
# 994    1995
# 995    1996
# 996    1997
# 997    1998
# 998    1999
# Name: userid, Length: 999, dtype: int64

# %%
df['userid'] = df['userid'].astype(float)
df
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001.0                   17                         634            1
# 1    1002.0                    0                          54            0
# 2    1003.0                   37                         207            0
# 3    1004.0                   32                         445            1
# 4    1005.0                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994  1995.0                   38                         938            0
# 995  1996.0                   43                          61            0
# 996  1997.0                   47                         761            0
# 997  1998.0                    6                          73            1
# 998  1999.0                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df.filter(items = ['userid' , 'status'])
# Out:
#      userid
# 0    1001.0
# 1    1002.0
# 2    1003.0
# 3    1004.0
# 4    1005.0
# ..      ...
# 994  1995.0
# 995  1996.0
# 996  1997.0
# 997  1998.0
# 998  1999.0
#
# [999 rows x 1 columns]

# %%
df.loc[5:8]
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 5  1006.0                   28                         599            0
# 6  1007.0                   49                         887            1
# 7  1008.0                    8                          31            0
# 8  1009.0                   28                         741            1
#
#    Ratings  New Password Request  Last Visited Minutes     Status
# 5        9                     4                  2878  Installed
# 6        9                     6                  4481  Installed
# 7        2                     1                  1715  Installed
# 8        8                     2                   801  Installed

# %%
df.values
# Out:
# array([[1001.0, 17, 634, ..., 7, 2990, 'Installed'],
#        [1002.0, 0, 54, ..., 8, 24008, 'Uninstalled'],
#        [1003.0, 37, 207, ..., 5, 971, 'Installed'],
#        ...,
#        [1997.0, 47, 761, ..., 1, 1936, 'Installed'],
#        [1998.0, 6, 73, ..., 1, 3436, 'Installed'],
#        [1999.0, 9, 54, ..., 2, 4039, 'Installed']], dtype=object)

# %%
a = df.columns

# %%
a = a.to_list()

a[0] = "user name"
a[4] = "remaning review"

# %%
a
# Out:
# ['user name',
#  'Average Screen Time',
#  'Average Spent on App (INR)',
#  'Left Review',
#  'remaning review',
#  'New Password Request',
#  'Last Visited Minutes',
#  'Status']

# %%
new_df = pd.DataFrame(df.values , columns = a)

# %%
new_df
# Out:
#     user name Average Screen Time Average Spent on App (INR) Left Review  \
# 0      1001.0                  17                        634           1
# 1      1002.0                   0                         54           0
# 2      1003.0                  37                        207           0
# 3      1004.0                  32                        445           1
# 4      1005.0                  45                        427           1
# ..        ...                 ...                        ...         ...
# 994    1995.0                  38                        938           0
# 995    1996.0                  43                         61           0
# 996    1997.0                  47                        761           0
# 997    1998.0                   6                         73           1
# 998    1999.0                   9                         54           0
#
#     remaning review New Password Request Last Visited Minutes       Status
# ...

# %%
df = df.rename(columns = {"age":"latest_age" , "city":"latest_city"})
df
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001.0                   17                         634            1
# 1    1002.0                    0                          54            0
# 2    1003.0                   37                         207            0
# 3    1004.0                   32                         445            1
# 4    1005.0                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994  1995.0                   38                         938            0
# 995  1996.0                   43                          61            0
# 996  1997.0                   47                         761            0
# 997  1998.0                    6                          73            1
# 998  1999.0                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df.to_csv("test.csv" , index =False )

# %%
df.to_excel("test.xlsx" , index = False)

# %%
df=pd.read_excel("/content/test.xlsx")

# %%
df =df.dropna()

# %%
df.loc[15:20]
# Out:
#     userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 15    1016                   11                         169            0
# 16    1017                   38                         776            1
# 17    1018                   34                         341            0
# 18    1019                   21                         250            0
# 19    1020                   18                         967            1
# 20    1021                   15                         774            1
#
#     Ratings  New Password Request  Last Visited Minutes     Status
# 15       10                     3                   577  Installed
# 16        7                     4                  2965  Installed
# 17        6                     1                  3124  Installed
# 18        7                     5                  3460  Installed
# 19       10                     6                  1925  Installed
# ...
